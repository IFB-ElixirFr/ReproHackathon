# %%
import cv2
import os
import datetime
import pandas
from openalea.phenomenal.calibration import CalibrationCamera


PREFIX='/ifb/data/public/teachdata/reprohack3/ARCH2016-04-15/binaries'

## read index
def read_index(prefix=os.path.join(PREFIX,'..')):
	df = pandas.read_csv(os.path.join(prefix, 'ZA16_organized_database.csv'),sep=';')
	for col in ('path_http','camera_angle', 'dates', 'view_type'):
		df.loc[:,col] = map(eval, df.loc[:,col])
	return df

## binary path
def get_remote_path_bin(row, prefix=PREFIX, delta=0):
    pot_number = int(row["plant"][:4])

    date = datetime.datetime.strptime(row["date"], "%Y-%m-%d %H:%M:%S.%f")
    date = date + datetime.timedelta(seconds=delta)
    str_date = date.strftime('%Y-%m-%d_%H-%M-%S')

    str_views = ['sv' if v == 'side' else 'tv' for v in row["view_type"]]

    filenames = list()
    for filename, view, angle, date in zip(row["path_http"],
                                           str_views,
                                           row["camera_angle"],
                                           row["dates"]):

        r = filename.split('/')


        # ZA16
        f = (prefix+
            '/task_{task}/'
            't-{task}_p-{pot}_{view}{angle}_{date}_bin.png'.format(
                name_exp=r[5],
                task=r[6],
                pot=pot_number,
                view=view,
                angle=angle,
                date=str_date))

        filenames.append(f)

    return filenames


def get_bin_images(row, prefix=PREFIX):
	#find filenames
	for delta in [0, -1, 1, -2, 2, -3, 3, -4, 4]:
		filenames = get_remote_path_bin(row, prefix=prefix,delta=delta)
		if os.path.exists(filenames[0]):
			break
	if delta == 4:
		raise ValueError('Can not find binaries')
	imdict={t:{} for t in set(row.view_type)}
	for view, angle, path in zip(row.view_type,row.camera_angle,filenames):
		imdict[view][angle]=cv2.imread(path, cv2.IMREAD_UNCHANGED)
	return imdict


def get_calibrations(row, prefix=os.path.join(PREFIX,'..','calibration')):
	calib = {}
	for view in set(row.view_type):
		path = os.path.join(prefix, (row.cabin + '_' + view + '_1_1_wide.json'))
		calib[view] = CalibrationCamera.load(path)
	return calib

# %% [markdown]
# # Plant growth animation

# %%
# %matplotlib notebook

import cv2

import openalea.phenomenal.data as phm_data 
import openalea.phenomenal.display as phm_display
import openalea.phenomenal.object as phm_obj
import openalea.phenomenal.multi_view_reconstruction as phm_mvr
import openalea.phenomenal.mesh as phm_mesh
import openalea.phenomenal.display.notebook as phm_display_notebook

# %% [markdown]
# ## Load data

# %%
df = read_index()
df.head()
# Out:
#       cabin                                       camera_angle  \
# 0  elcom_c1  [330, 300, 270, 240, 210, 150, 180, 90, 120, 3...
# 1  elcom_c2  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 2  elcom_c2  [330, 270, 300, 210, 240, 150, 180, 90, 120, 3...
# 3  elcom_c2  [330, 270, 300, 210, 240, 150, 180, 90, 120, 3...
# 4  elcom_c2  [330, 270, 300, 210, 240, 150, 180, 90, 120, 3...
#
#                          date  \
# 0  2016-05-18 04:30:13.018825
# 1  2016-05-19 03:50:35.300685
# 2  2016-05-20 06:52:56.492283
# 3  2016-05-22 04:05:34.442505
# 4  2016-05-23 04:05:23.606912
#
#                                                dates     daydate experiment  \
# 0  [2016-05-18 04:30:13.018825, 2016-05-18 04:30:...  18/05/2016       ZA16
# 1  [2016-05-19 03:50:35.300685, 2016-05-19 03:50:...  19/05/2016       ZA16
# 2  [2016-05-20 06:52:56.492283, 2016-05-20 06:52:...  20/05/2016       ZA16
# 3  [2016-05-22 04:05:34.442505, 2016-05-22 04:05:...  22/05/2016       ZA16
# 4  [2016-05-23 04:05:23.606912, 2016-05-23 04:05:...  23/05/2016       ZA16
#
#    genotype  nview                                          path_http  \
# 0  Lo1270_H     13  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1  Lo1270_H     13  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 2  Lo1270_H     13  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 3  Lo1270_H     13  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 4  Lo1270_H     13  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
#
#                                                plant   shooting_frame  task  \
# 0  0001/Lo1270_H/ZM2887/d151/WD/3/01_01/ARCH2016-...  elcom_2_c1_wide  5236
# 1  0001/Lo1270_H/ZM2887/d151/WD/3/01_01/ARCH2016-...  elcom_2_c2_wide  5240
# 2  0001/Lo1270_H/ZM2887/d151/WD/3/01_01/ARCH2016-...  elcom_2_c2_wide  5248
# 3  0001/Lo1270_H/ZM2887/d151/WD/3/01_01/ARCH2016-...  elcom_2_c2_wide  5269
# 4  0001/Lo1270_H/ZM2887/d151/WD/3/01_01/ARCH2016-...  elcom_2_c2_wide  5270
#
#     timestamp                                                uri  \
# 0  1463538613  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1  1463622635  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 2  1463719976  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 3  1463882734  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 4  1463969123  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
#
#                                            view_type  pos  line
# 0  [side, side, side, side, side, side, side, sid...    1     1
# 1  [side, side, side, side, side, side, side, sid...    1     1
# 2  [side, side, side, side, side, side, side, sid...    1     1
# 3  [side, side, side, side, side, side, side, sid...    1     1
# 4  [side, side, side, side, side, side, side, sid...    1     1

# %%
df.shape[0]
# Out:
# 57437

# %% [markdown]
# ## Select 1 plant

# %%
dfl = df[df.plant == df.plant[1500]]

# %%
dfl.shape[0]
# Out:
# 26

# %%
dfl = dfl.sort_values(['date'])

# %%
dfl.head()
# Out:
#          cabin                                       camera_angle  \
# 1481  elcom_c2  [330, 270, 300, 210, 240, 150, 180, 120, 90, 6...
# 1482  elcom_c2  [330, 270, 300, 210, 240, 150, 180, 90, 120, 3...
# 1483  elcom_c1  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 1484  elcom_c1  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 1485  elcom_c1  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 1486  elcom_c1  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 1487  elcom_c1  [330, 270, 300, 210, 240, 150, 180, 90, 120, 3...
# 1488  elcom_c1  [330, 270, 300, 210, 240, 150, 180, 90, 120, 3...
# 1489  elcom_c1  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 1490  elcom_c1  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 1491  elcom_c1  [330, 270, 300, 210, 240, 150, 180, 90, 120, 3...
# 1492  elcom_c1  [300, 330, 240, 270, 180, 210, 150, 120, 90, 6...
# 1493  elcom_c1  [330, 0, 270, 300, 210, 240, 150, 180, 90, 120...
# 1494  elcom_c1  [330, 270, 300, 210, 240, 180, 150, 120, 90, 6...
# 1495  elcom_c1  [300, 330, 270, 240, 210, 180, 150, 120, 90, 6...
# 1496  elcom_c1  [330, 300, 270, 240, 210, 180, 120, 150, 60, 9...
# 1498  elcom_c1  [330, 300, 270, 240, 180, 210, 120, 150, 60, 9...
# 1497  elcom_c1  [330, 300, 240, 270, 180, 210, 120, 150, 60, 9...
# 1499  elcom_c1  [300, 330, 240, 270, 180, 210, 120, 150, 60, 9...
# 1500  elcom_c1  [30, 0, 60, 90, 120, 150, 180, 210, 240, 270, ...
# 1501  elcom_c1  [0, 0, 30, 60, 90, 120, 150, 180, 210, 240, 27...
# 1502  elcom_c1  [0, 0, 30, 60, 90, 120, 150, 180, 210, 240, 27...
# 1503  elcom_c1  [0, 0, 30, 60, 90, 120, 150, 180, 210, 240, 27...
# 1505  elcom_c1  [0, 0, 30, 60, 90, 120, 150, 180, 210, 240, 27...
# 1504  elcom_c1  [0, 0, 30, 60, 90, 120, 150, 180, 210, 240, 27...
# 1506  elcom_c1  [0, 0, 30, 60, 90, 120, 150, 180, 210, 240, 27...
#
#                             date  \
# 1481  2016-05-18 04:52:56.427868
# 1482  2016-05-19 04:13:22.755899
# 1483  2016-05-20 07:14:35.574526
# 1484  2016-05-22 04:27:12.565693
# 1485  2016-05-23 04:26:54.472456
# 1486  2016-05-25 04:26:13.629714
# 1487  2016-05-27 04:58:38.249535
# 1488  2016-05-29 04:26:52.796144
# 1489  2016-05-30 04:27:15.093686
# 1490  2016-06-01 04:30:09.673266
# 1491  2016-06-02 05:35:02.861741
# 1492  2016-06-03 04:32:25.428625
# 1493  2016-06-05 06:11:30.860279
# 1494  2016-06-06 04:56:19.602365
# 1495  2016-06-08 04:59:21.854384
# 1496  2016-06-09 05:24:17.790744
# 1498  2016-06-09 13:43:27.267756
# 1497  2016-06-10 06:37:16.190972
# 1499  2016-06-12 04:36:01.262464
# 1500  2016-06-15 04:07:58.792145
# 1501  2016-06-16 05:15:24.372337
# 1502  2016-06-17 04:22:59.324248
# 1503  2016-06-18 04:23:18.488141
# 1505  2016-06-20 19:17:33.232612
# 1504  2016-06-21 01:11:39.279816
# 1506  2016-06-21 14:46:27.370055
#
#                                                   dates     daydate  \
# 1481  [2016-05-18 04:52:56.427868, 2016-05-18 04:52:...  18/05/2016
# 1482  [2016-05-19 04:13:22.755899, 2016-05-19 04:13:...  19/05/2016
# 1483  [2016-05-20 07:14:35.574526, 2016-05-20 07:14:...  20/05/2016
# 1484  [2016-05-22 04:27:12.565693, 2016-05-22 04:27:...  22/05/2016
# 1485  [2016-05-23 04:26:54.472456, 2016-05-23 04:26:...  23/05/2016
# 1486  [2016-05-25 04:26:13.629714, 2016-05-25 04:26:...  25/05/2016
# 1487  [2016-05-27 04:58:38.249535, 2016-05-27 04:58:...  27/05/2016
# 1488  [2016-05-29 04:26:52.796144, 2016-05-29 04:26:...  29/05/2016
# 1489  [2016-05-30 04:27:15.093686, 2016-05-30 04:27:...  30/05/2016
# 1490  [2016-06-01 04:30:09.673266, 2016-06-01 04:30:...  01/06/2016
# 1491  [2016-06-02 05:35:02.861741, 2016-06-02 05:35:...  02/06/2016
# 1492  [2016-06-03 04:32:25.428625, 2016-06-03 04:32:...  03/06/2016
# 1493  [2016-06-05 06:11:30.860279, 2016-06-05 06:11:...  05/06/2016
# 1494  [2016-06-06 04:56:19.602365, 2016-06-06 04:56:...  06/06/2016
# 1495  [2016-06-08 04:59:21.854384, 2016-06-08 04:59:...  08/06/2016
# 1496  [2016-06-09 05:24:17.790744, 2016-06-09 05:24:...  09/06/2016
# 1498  [2016-06-09 13:43:27.267756, 2016-06-09 13:43:...  09/06/2016
# 1497  [2016-06-10 06:37:16.190972, 2016-06-10 06:37:...  10/06/2016
# 1499  [2016-06-12 04:36:01.262464, 2016-06-12 04:36:...  12/06/2016
# 1500  [2016-06-15 04:07:58.792145, 2016-06-15 04:07:...  15/06/2016
# 1501  [2016-06-16 05:15:24.372337, 2016-06-16 05:15:...  16/06/2016
# 1502  [2016-06-17 04:22:59.324248, 2016-06-17 04:22:...  17/06/2016
# 1503  [2016-06-18 04:23:18.488141, 2016-06-18 04:23:...  18/06/2016
# 1505  [2016-06-20 19:17:33.232612, 2016-06-20 19:17:...  20/06/2016
# 1504  [2016-06-21 01:11:39.279816, 2016-06-21 01:11:...  21/06/2016
# 1506  [2016-06-21 14:46:27.370055, 2016-06-21 14:46:...  21/06/2016
#
#      experiment  genotype  nview  \
# 1481       ZA16  DKMBST_H     13
# 1482       ZA16  DKMBST_H     13
# 1483       ZA16  DKMBST_H     13
# 1484       ZA16  DKMBST_H     13
# 1485       ZA16  DKMBST_H     13
# 1486       ZA16  DKMBST_H     13
# 1487       ZA16  DKMBST_H     13
# 1488       ZA16  DKMBST_H     13
# 1489       ZA16  DKMBST_H     13
# 1490       ZA16  DKMBST_H     13
# 1491       ZA16  DKMBST_H     13
# 1492       ZA16  DKMBST_H     13
# 1493       ZA16  DKMBST_H     13
# 1494       ZA16  DKMBST_H     13
# 1495       ZA16  DKMBST_H     13
# 1496       ZA16  DKMBST_H     13
# 1498       ZA16  DKMBST_H     13
# 1497       ZA16  DKMBST_H     13
# 1499       ZA16  DKMBST_H     13
# 1500       ZA16  DKMBST_H     13
# 1501       ZA16  DKMBST_H     13
# 1502       ZA16  DKMBST_H     13
# 1503       ZA16  DKMBST_H     13
# 1505       ZA16  DKMBST_H     13
# 1504       ZA16  DKMBST_H     13
# 1506       ZA16  DKMBST_H     13
#
#                                               path_http  \
# 1481  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1482  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1483  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1484  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1485  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1486  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1487  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1488  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1489  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1490  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1491  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1492  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1493  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1494  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1495  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1496  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1498  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1497  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1499  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1500  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1501  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1502  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1503  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1505  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1504  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
# 1506  [http://stck-lepse.supagro.inra.fr/phenoarch/r...
#
#                                                   plant   shooting_frame  \
# 1481  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c2_wide
# 1482  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c2_wide
# 1483  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1484  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1485  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1486  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1487  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1488  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1489  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1490  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1491  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1492  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1493  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1494  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1495  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1496  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1498  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1497  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1499  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1500  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1501  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1502  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1503  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1505  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1504  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
# 1506  0058/DKMBST_H/ZM2800/d89/WD/3/01_58/ARCH2016-0...  elcom_2_c1_wide
#
#       task   timestamp                                                uri  \
# 1481  5236  1463539976  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1482  5240  1463624002  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1483  5248  1463721275  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1484  5269  1463884032  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1485  5270  1463970414  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1486  5278  1464143173  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1487  5292  1464317918  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1488  5302  1464488812  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1489  5307  1464575235  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1490  5329  1464748209  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1491  5333  1464838502  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1492  5347  1464921145  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1493  5364  1465099890  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1494  5369  1465181779  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1495  5386  1465354761  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1496  5395  1465442657  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1498  5401  1465472607  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1497  5399  1465533436  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1499  5412  1465698961  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1500  5439  1465956478  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1501  5445  1466046924  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1502  5451  1466130179  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1503  5456  1466216598  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1505  5490  1466443053  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1504  5486  1466464299  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
# 1506  5491  1466513187  [u'http://www.phenome-fppn.fr/m3p/arch/2016/ic...
#
#                                               view_type  pos  line
# 1481  [side, side, side, side, side, side, side, sid...   58     1
# 1482  [side, side, side, side, side, side, side, sid...   58     1
# 1483  [side, side, side, side, side, side, side, sid...   58     1
# 1484  [side, side, side, side, side, side, side, sid...   58     1
# 1485  [side, side, side, side, side, side, side, sid...   58     1
# 1486  [side, side, side, side, side, side, side, sid...   58     1
# 1487  [side, side, side, side, side, side, side, sid...   58     1
# 1488  [side, side, side, side, side, side, side, sid...   58     1
# 1489  [side, side, side, side, side, side, side, sid...   58     1
# 1490  [side, side, side, side, side, side, side, sid...   58     1
# 1491  [side, side, side, side, side, side, side, sid...   58     1
# 1492  [side, side, side, side, side, side, side, sid...   58     1
# 1493  [side, side, side, side, side, side, side, sid...   58     1
# 1494  [side, side, side, side, side, side, side, sid...   58     1
# 1495  [side, side, side, side, side, side, side, sid...   58     1
# 1496  [side, side, side, side, side, side, side, sid...   58     1
# 1498  [side, side, side, side, side, side, side, sid...   58     1
# 1497  [side, side, side, side, side, side, side, sid...   58     1
# 1499  [side, side, side, side, side, side, side, sid...   58     1
# 1500  [side, top, side, side, side, side, side, side...   58     1
# 1501  [side, top, side, side, side, side, side, side...   58     1
# 1502  [side, top, side, side, side, side, side, side...   58     1
# 1503  [side, top, side, side, side, side, side, side...   58     1
# 1505  [side, top, side, side, side, side, side, side...   58     1
# 1504  [side, top, side, side, side, side, side, side...   58     1
# 1506  [side, top, side, side, side, side, side, side...   58     1

# %%
def routine_select_ref_angle(bin_side_images):

    max_len = 0
    max_angle = None
    
    for angle in bin_side_images:
    
        x_pos, y_pos, x_len, y_len = cv2.boundingRect(cv2.findNonZero(bin_side_images[angle]))

        if x_len > max_len:
            max_len = x_len
            max_angle = angle

    return max_angle

# %%
voxels_size = 8 # mm
error_tolerance = 2
plants_voxels = []
for plant_number in range(0, dfl.shape[0]):
    rpd = get_remote_path_bin(df.loc[plant_number])
    calibrations = get_calibrations(row=df.loc[plant_number])
    bin_images = get_bin_images(row=df.loc[plant_number])
    
    refs_angle_list = [routine_select_ref_angle(bin_images["side"])]

    image_views = list()
    for id_camera in bin_images:
        for angle in bin_images[id_camera]:
            projection = calibrations[id_camera].get_projection(angle)

            image_ref = None
            if id_camera == "side" and angle in refs_angle_list:
                image_ref = bin_images[id_camera][angle]

            inclusive = False
            if id_camera == "top":
                inclusive = True

            image_views.append(phm_obj.ImageView(
                bin_images[id_camera][angle], 
                projection, 
                inclusive=inclusive, 
                image_ref=image_ref))
            
    plants_voxels.append(
        phm_mvr.reconstruction_3d(
            image_views, 
            voxels_size=voxels_size,
            error_tolerance=error_tolerance)
    )

# %% [markdown]
# ## Test voxels

# %%
phm_display_notebook.show_voxel_grid(plants_voxels[0], size=1)
# Out:
# VkJveChjaGlsZHJlbj0oRmlndXJlKGNhbWVyYT1QZXJzcGVjdGl2ZUNhbWVyYShmb3Y9NDYuMCwgcG9zaXRpb249KDAuMCwgMi4wLCAxLjIyNDY0Njc5OTE0NzM1MzJlLTE2KSwgcXVhdGVybmnigKY=

# %%
phm_display_notebook.show_voxel_grid(plants_voxels[25], size=1)
# Out:
# VkJveChjaGlsZHJlbj0oRmlndXJlKGNhbWVyYT1QZXJzcGVjdGl2ZUNhbWVyYShmb3Y9NDYuMCwgcG9zaXRpb249KDAuMCwgMi4wLCAxLjIyNDY0Njc5OTE0NzM1MzJlLTE2KSwgcXVhdGVybmnigKY=

# %% [markdown]
# ## Serialize

# %%
for i, voxel_grid in enumerate(plants_voxels):
    voxel_grid.write("voxel_{}_size_{}.npz".format(i, voxels_size))

# %% [markdown]
# ### Build meshes

# %%
meshes = []
for i, voxel_grid in enumerate(plants_voxels):
    vertices, faces = phm_mesh.meshing(
        voxel_grid.to_image_3d(),
        reduction=0.90,
        smoothing_iteration=5,
        verbose=True
    )
    meshes.append(
        dict(vertices=vertices, faces=faces)
    )
# Out:
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 498 points.
# 	There are 955 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 498 points.
# 	There are 955 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 498 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 702 points.
# 	There are 1358 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 702 points.
# 	There are 1358 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 702 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 887 points.
# 	There are 1736 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 887 points.
# 	There are 1736 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 887 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 1420 points.
# 	There are 2794 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 1420 points.
# 	There are 2794 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 1420 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 1785 points.
# 	There are 3534 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 1785 points.
# 	There are 3534 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 1785 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 2444 points.
# 	There are 4838 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 2444 points.
# 	There are 4838 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 2444 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 3709 points.
# 	There are 7358 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 3709 points.
# 	There are 7358 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 3709 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 5236 points.
# 	There are 10404 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 5236 points.
# 	There are 10404 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 5236 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 6031 points.
# 	There are 12012 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 6031 points.
# 	There are 12012 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 6031 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 9236 points.
# 	There are 18416 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 9236 points.
# 	There are 18416 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 9236 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 10591 points.
# 	There are 21076 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 10591 points.
# 	There are 21076 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 10591 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 12560 points.
# 	There are 24984 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 12560 points.
# 	There are 24984 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 12560 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 15835 points.
# 	There are 31504 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 15835 points.
# 	There are 31504 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 15835 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 16147 points.
# 	There are 32164 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 16147 points.
# 	There are 32164 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 16147 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 18637 points.
# 	There are 37092 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 18637 points.
# 	There are 37092 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 18637 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 18849 points.
# 	There are 37540 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 18849 points.
# 	There are 37540 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 18849 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 19197 points.
# 	There are 38196 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 19197 points.
# 	There are 38196 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 19197 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 19540 points.
# 	There are 38868 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 19540 points.
# 	There are 38868 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 19540 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 21548 points.
# 	There are 42932 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 21548 points.
# 	There are 42932 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 21548 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 23378 points.
# 	There are 46554 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 23378 points.
# 	There are 46554 polygons.
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 23378 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 25997 points.
# 	There are 51724 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 25997 points.
# 	There are 51724 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 25997 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 27756 points.
# 	There are 55312 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 27756 points.
# 	There are 55312 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 27756 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 29946 points.
# 	There are 59678 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 29946 points.
# 	There are 59678 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 29946 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 33209 points.
# 	There are 66096 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 33209 points.
# 	There are 66096 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 33209 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 31943 points.
# 	There are 63646 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 31943 points.
# 	There are 63646 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 31943 polygons.
# ================================================================================
# ================================================================================
# Marching cubes :
# 	Iso value :0.5
#
# 	There are 36483 points.
# 	There are 72632 polygons.
# ================================================================================
# ================================================================================
# Smoothing :
# 	Feature angle :120.0
# 	Number of iteration :5
# 	Pass band : 0.01
#
# ================================================================================
# ================================================================================
# Decimation :
# 	Reduction (percentage) :0.9
#
# 	Before decimation
# 	-----------------
# 	There are 36483 points.
# 	There are 72632 polygons.
#
# 	After decimation
# 	-----------------
# 	There are 0.9 points.
# 	There are 36483 polygons.
# ================================================================================

# %%
phm_display_notebook.show_mesh(meshes[0]['vertices'], meshes[0]['faces'])
# Out:
# VkJveChjaGlsZHJlbj0oRmlndXJlKGNhbWVyYT1QZXJzcGVjdGl2ZUNhbWVyYShmb3Y9NDYuMCwgcG9zaXRpb249KDAuMCwgMi4wLCAxLjIyNDY0Njc5OTE0NzM1MzJlLTE2KSwgcXVhdGVybmnigKY=

# %%
phm_display_notebook.show_mesh(meshes[25]['vertices'], meshes[25]['faces'])
# Out:
# VkJveChjaGlsZHJlbj0oRmlndXJlKGNhbWVyYT1QZXJzcGVjdGl2ZUNhbWVyYShmb3Y9NDYuMCwgcG9zaXRpb249KDAuMCwgMi4wLCAxLjIyNDY0Njc5OTE0NzM1MzJlLTE2KSwgcXVhdGVybmnigKY=

# %%
import ipyvolume

# %% [markdown]
# ### Test ipyvolume plotting

# %%
x, y, z = (plants_voxels[25].voxels_position[:, 0],
           plants_voxels[25].voxels_position[:, 1],
           plants_voxels[25].voxels_position[:, 2])

ipyvolume.scatter(x, y, z, size=2, marker="box", color="green")

x_min = plants_voxels[25].voxels_position[:, 0].min()
x_max = plants_voxels[25].voxels_position[:, 0].max()
y_min = plants_voxels[25].voxels_position[:, 1].min()
y_max = plants_voxels[25].voxels_position[:, 1].max()
z_min = plants_voxels[25].voxels_position[:, 2].min()
z_max = plants_voxels[25].voxels_position[:, 2].max()

xyz_max = max(x_max - x_min, y_max - y_min, z_max - z_min)
ipyvolume.xlim(x_min, x_min + xyz_max)
ipyvolume.ylim(y_min, y_min + xyz_max)
ipyvolume.zlim(z_min, z_min + xyz_max)
ipyvolume.view(10, 10)
ipyvolume.show()
# Out:
# VkJveChjaGlsZHJlbj0oRmlndXJlKGNhbWVyYT1QZXJzcGVjdGl2ZUNhbWVyYShmb3Y9NDYuMCwgbWF0cml4V29ybGROZWVkc1VwZGF0ZT1UcnVlLCBwb3NpdGlvbj0oMC4zNTg3MjY4NTUyODjigKY=

# %%
plants_voxels[25].voxels_position[:, 0]
# Out:
# array([  68.,   44., -412., ...,  636.,  284.,  -36.])

# %%
len(plants_voxels[25].voxels_position[:, 0])
# Out:
# 32040

# %%
len(plants_voxels[0].voxels_position[:, 0])
# Out:
# 231

# %%
max_voxel_vertices = 0
for voxel_grid in plants_voxels:    
    if len(voxel_grid.voxels_position[:, 0]) > max_voxel_vertices:
        max_voxel_vertices = len(voxel_grid.voxels_position[:, 0])
max_voxel_vertices
# Out:
# 32040

# %% [markdown]
# ### Build animation voxels

# %%
import numpy as np

x_start = plants_voxels[0].voxels_position[0, 0]
y_start = plants_voxels[0].voxels_position[0, 1]
z_start = plants_voxels[0].voxels_position[0, 2]

x = [[x_start for i in range(0, max_voxel_vertices)] for _ in range(0, len(plants_voxels))]
y = [[y_start for i in range(0, max_voxel_vertices)] for _ in range(0, len(plants_voxels))]
z = [[z_start for i in range(0, max_voxel_vertices)] for _ in range(0, len(plants_voxels))]

for i, voxel_grid in enumerate(plants_voxels):
    xs = voxel_grid.voxels_position[:, 0]
    ys = voxel_grid.voxels_position[:, 1]
    zs = voxel_grid.voxels_position[:, 2]
    
    #pts = [[xs[k], ys[k], zs[k]] for k in range(len(voxel_grid.voxels_position[:, 0]))]
    #pts = sorted(pts, key =  lambda x: x[0]*x[0] + x[1]*x[1] +x[2]*x[2])
    
    #xs = []
    #ys = []
    #zs = []
    #for v in pts:
    #    xs.append(v[0])
    #    ys.append(v[1])
    #    zs.append(v[2])
    
    xs, ys, zs = zip(*sorted(zip(xs, ys, zs)))
    
    for j, xi in enumerate(xs):
        x[i][j] = xi 
    
    for j, yi in enumerate(ys):
        y[i][j] = yi
    
    for j, zi in enumerate(zs):
        z[i][j] = zi
        
x = np.array(x)
y = np.array(y)
z = np.array(z)

# %% [markdown]
# ### Build animaton

# %%
ipyvolume.figure()
s = ipyvolume.scatter(
    x, y, z, 
    color="green", 
    visible=True,
    marker='sphere', 
    size=1, 
    
    grow_limits=False
)
ipyvolume.xyzlim(-1, 1)
ipyvolume.animation_control(
    s, 
    interval=1000
) # shows controls for animation controls

x_min = plants_voxels[25].voxels_position[:, 0].min()
x_max = plants_voxels[25].voxels_position[:, 0].max()
y_min = plants_voxels[25].voxels_position[:, 1].min()
y_max = plants_voxels[25].voxels_position[:, 1].max()
z_min = plants_voxels[25].voxels_position[:, 2].min()
z_max = plants_voxels[25].voxels_position[:, 2].max()

xyz_max = max(x_max - x_min, y_max - y_min, z_max - z_min)
ipyvolume.xlim(x_min, x_min + xyz_max)
ipyvolume.ylim(y_min, y_min + xyz_max)
ipyvolume.zlim(z_min, z_min + xyz_max)

ipyvolume.show()
# Out:
# VkJveChjaGlsZHJlbj0oRmlndXJlKGNhbWVyYT1QZXJzcGVjdGl2ZUNhbWVyYShmb3Y9NDYuMCwgcG9zaXRpb249KDAuMCwgMC4wLCAyLjApLCBxdWF0ZXJuaW9uPSgwLjAsIDAuMCwgMC4wLCDigKY=
